# %% [markdown]
# # 2.1.3 Unsupervised learning algorithms dendrogram - VALENTIA-PCA
# ### The following script contains the following:
#
# #### 1. Import data libraries, additional requirements
# #### 2. Read scaled csv data set
# #### 3. Rerun dendrogram methods with dfPCA dimensionality reduction
# #### 4. Rerun dendrogram methods with dfPCA2 dimensionality reduction
# ---------------------------------------------------------------------------------------------------------------------------
# ## 1. Import data libraries, additional requirements
# ---------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.
# %matplotlib inline

# Turning off warning feature
import warnings
warnings.filterwarnings('ignore')

# Supress scientific notation for easier analysis profiling
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 2. Read scaled csv data set

# %%
path = r'climatewins-ml'

# %%
dfPCA = pd.read_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'PCA1.csv'))

# %%
dfPCA2 = pd.read_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'PCA2.csv'))

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 3. Rerun dendrogram methods with dfPCA dimensionality reduction

# %%
distance_single_pca = linkage(dfPCA, method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single_pca, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Single Method (PCA)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Single Method (PCA)')

# %%
distance_complete_pca = linkage(dfPCA, method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_complete_pca, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Complete Method (PCA)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Complete Method (PCA)')

# %%
distance_average_pca = linkage(dfPCA, method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average_pca, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Average Method (PCA)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Average Method (PCA)')

# %%
distance_ward = linkage(dfPCA, method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Ward Method (PCA)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Ward Method (PCA)')

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 3. Rerun dendrogram methods with dfPCA2 dimensionality reduction

# %%
distance_single_pca2 = linkage(dfPCA2, method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single_pca, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Single Method (PCA2)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Single Method (PCA2)')

# %%
distance_complete_pca2 = linkage(dfPCA2, method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_complete_pca, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Complete Method (PCA2)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Complete Method (PCA2)')

# %%
distance_average_pca2 = linkage(dfPCA2, method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average_pca, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Average Method (PCA2)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Average Method (PCA2)')

# %%
distance_ward2 = linkage(dfPCA2, method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Ward Method (PCA2)",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Ward Method (PCA2)')

# %% [markdown]
# **Note:** no difference in reduction methods

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
