# %% [markdown]
# # 2.1.2 Unsupervised learning algorithms dendrogram
# ### The following script contains the following:
#
# #### 1. Import data libraries, additional requirements
# #### 2. Read scaled csv data set
# #### 3. Scale the data features
#         - export new scaled data 'unsupervised' folder
# #### 4. Scale down the features of VALENTIA for last decade
# #### 5. Create dendrogram
#         - single
#         - complete
#         - average
#         - ward
# #### 6. Dimensionality reduction
#         - PCA
# ---------------------------------------------------------------------------------------------------------------------------
# ## 1. Import data libraries, additional requirements
# ---------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.
# %matplotlib inline

# Turning off warning feature
import warnings
warnings.filterwarnings('ignore')

# Supress scientific notation for easier analysis profiling
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 2. Read scaled csv data set

# %%
path = r'climatewins-ml'

# %%
pleasant = pd.read_csv(os.path.join(path, '02 Data Sets', 'Original Data', 'Weather_Prediction_Pleasant_Weather.csv'))

# %%
scaled = pd.read_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'weather_data_scaled.csv'))
scaled
# Out:
#            DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0      19600101      1               0.66             -0.03            0.83
# 1      19600102      1               0.24             -0.03            0.74
# 2      19600103      1               1.08             -0.03            1.28
# 3      19600104      1              -1.00             -0.03            1.46
# 4      19600105      1               0.24             -0.03            1.73
# ...         ...    ...                ...               ...             ...
# 22945  20221027     10              -1.83             -0.03            0.28
# 22946  20221028     10               0.24             -0.03            0.10
# 22947  20221029     10              -0.59             -0.03            0.01
# 22948  20221030     10              -0.17             -0.03            0.37
# 22949  20221031     10              -0.17             -0.03            0.74
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0               -0.00                   -1.10                -0.27
# 1               -0.00                   -1.06                 1.66
# 2               -0.00                   -1.25                 0.16
# 3               -0.00                   -0.82                -0.45
# 4               -0.00                   -0.75                -0.16
# ...               ...                     ...                  ...
# 22945            1.04                   -0.01                -0.00
# 22946            0.98                   -0.01                -0.00
# 22947            0.72                   -0.01                -0.00
# 22948            0.49                   -0.01                -0.00
# 22949            0.20                   -0.01                -0.00
#
#        BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 -0.18           -0.90  ...                 -0.44
# 1                 -0.18           -0.81  ...                  0.78
# 2                 -0.18           -1.07  ...                  0.78
# 3                 -0.18           -0.11  ...                  0.78
# 4                 -0.18            0.19  ...                 -1.67
# ...                 ...             ...  ...                   ...
# 22945             -0.18            0.72  ...                 -0.44
# 22946             -0.18            0.19  ...                 -0.44
# 22947             -0.18            0.35  ...                 -0.44
# 22948             -0.18            0.28  ...                 -0.44
# 22949             -0.18           -0.32  ...                 -0.44
#
#        VALENTIA_humidity  VALENTIA_pressure  VALENTIA_global_radiation  \
# 0                   0.76              -1.30                      -0.81
# 1                   1.18              -1.26                      -1.04
# 2                   1.18              -0.43                      -1.14
# 3                   0.48               0.39                      -1.18
# 4                  -0.36               1.73                      -0.79
# ...                  ...                ...                        ...
# 22945              -0.08              -0.00                      -0.01
# 22946              -0.08              -0.00                      -0.01
# 22947              -0.08              -0.00                      -0.01
# 22948              -0.08              -0.00                      -0.01
# 22949              -0.08              -0.00                      -0.01
#
#        VALENTIA_precipitation  VALENTIA_snow_depth  VALENTIA_sunshine  \
# 0                       -0.09                -0.02               0.37
# 1                        0.50                -0.02              -0.83
# 2                       -0.40                -0.02              -1.01
# 3                        0.67                -0.02              -1.04
# 4                       -0.49                -0.02               0.67
# ...                       ...                  ...                ...
# 22945                   -0.01                -0.02              -0.02
# 22946                   -0.01                -0.02              -0.02
# 22947                   -0.01                -0.02              -0.02
# 22948                   -0.01                -0.02              -0.02
# 22949                   -0.01                -0.02              -0.02
#
#        VALENTIA_temp_mean  VALENTIA_temp_min  VALENTIA_temp_max
# 0                   -0.67              -0.52              -0.75
# 1                   -0.55              -0.63              -0.41
# 2                   -0.07               0.05              -0.18
# 3                   -1.00              -0.16              -0.84
# 4                   -1.51              -1.34              -1.47
# ...                   ...                ...                ...
# 22945               -0.01              -0.00              -0.00
# 22946               -0.01              -0.00              -0.00
# 22947               -0.01              -0.00              -0.00
# 22948               -0.01              -0.00              -0.00
# 22949               -0.01              -0.00              -0.00
#
# [22950 rows x 170 columns]

# %%
# Drop the DATE and MONTH data as those numbers are not scaled with the rest.
drop_features = scaled.drop(['MONTH',
                         # GDANSK features
                         'GDANSK_cloud_cover', 'GDANSK_humidity',
                         'GDANSK_precipitation', 'GDANSK_snow_depth',
                         'GDANSK_temp_mean', 'GDANSK_temp_min', 'GDANSK_temp_max',
                         # ROMA features
                         'ROMA_cloud_cover', 'ROMA_humidity', 'ROMA_pressure',
                         'ROMA_sunshine', 'ROMA_temp_mean',
                         # TOURS features
                         'TOURS_humidity', 'TOURS_pressure',
                         'TOURS_global_radiation', 'TOURS_precipitation',
                         'TOURS_temp_mean', 'TOURS_temp_min', 'TOURS_temp_max'], axis=1)
drop_features
# Out:
#            DATE  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0      19600101               0.66             -0.03            0.83
# 1      19600102               0.24             -0.03            0.74
# 2      19600103               1.08             -0.03            1.28
# 3      19600104              -1.00             -0.03            1.46
# 4      19600105               0.24             -0.03            1.73
# ...         ...                ...               ...             ...
# 22945  20221027              -1.83             -0.03            0.28
# 22946  20221028               0.24             -0.03            0.10
# 22947  20221029              -0.59             -0.03            0.01
# 22948  20221030              -0.17             -0.03            0.37
# 22949  20221031              -0.17             -0.03            0.74
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0               -0.00                   -1.10                -0.27
# 1               -0.00                   -1.06                 1.66
# 2               -0.00                   -1.25                 0.16
# 3               -0.00                   -0.82                -0.45
# 4               -0.00                   -0.75                -0.16
# ...               ...                     ...                  ...
# 22945            1.04                   -0.01                -0.00
# 22946            0.98                   -0.01                -0.00
# 22947            0.72                   -0.01                -0.00
# 22948            0.49                   -0.01                -0.00
# 22949            0.20                   -0.01                -0.00
#
#        BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  ...  \
# 0                 -0.18           -0.90            -0.53  ...
# 1                 -0.18           -0.81            -0.58  ...
# 2                 -0.18           -1.07            -0.26  ...
# 3                 -0.18           -0.11            -0.56  ...
# 4                 -0.18            0.19            -1.00  ...
# ...                 ...             ...              ...  ...
# 22945             -0.18            0.72             0.75  ...
# 22946             -0.18            0.19             0.86  ...
# 22947             -0.18            0.35             0.86  ...
# 22948             -0.18            0.28             0.68  ...
# 22949             -0.18           -0.32             0.42  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 0                     -0.44               0.76              -1.30
# 1                      0.78               1.18              -1.26
# 2                      0.78               1.18              -0.43
# 3                      0.78               0.48               0.39
# 4                     -1.67              -0.36               1.73
# ...                     ...                ...                ...
# 22945                 -0.44              -0.08              -0.00
# 22946                 -0.44              -0.08              -0.00
# 22947                 -0.44              -0.08              -0.00
# 22948                 -0.44              -0.08              -0.00
# 22949                 -0.44              -0.08              -0.00
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 0                          -0.81                   -0.09                -0.02
# 1                          -1.04                    0.50                -0.02
# 2                          -1.14                   -0.40                -0.02
# 3                          -1.18                    0.67                -0.02
# 4                          -0.79                   -0.49                -0.02
# ...                          ...                     ...                  ...
# 22945                      -0.01                   -0.01                -0.02
# 22946                      -0.01                   -0.01                -0.02
# 22947                      -0.01                   -0.01                -0.02
# 22948                      -0.01                   -0.01                -0.02
# 22949                      -0.01                   -0.01                -0.02
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 0                   0.37               -0.67              -0.52
# 1                  -0.83               -0.55              -0.63
# 2                  -1.01               -0.07               0.05
# 3                  -1.04               -1.00              -0.16
# 4                   0.67               -1.51              -1.34
# ...                  ...                 ...                ...
# 22945              -0.02               -0.01              -0.00
# 22946              -0.02               -0.01              -0.00
# 22947              -0.02               -0.01              -0.00
# 22948              -0.02               -0.01              -0.00
# 22949              -0.02               -0.01              -0.00
#
#        VALENTIA_temp_max
# 0                  -0.75
# 1                  -0.41
# 2                  -0.18
# 3                  -0.84
# 4                  -1.47
# ...                  ...
# 22945              -0.00
# 22946              -0.00
# 22947              -0.00
# 22948              -0.00
# 22949              -0.00
#
# [22950 rows x 150 columns]

# %%
# Save fully scaled dataset without 3 weather stations [ROMA, GDANSK, TOURS]

drop_features.to_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'scaled-full-drop-3-stations.csv'), index=False)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 4. Scale down the features of VALENTIA for last decade

# %%
# Merge data sets using (inner join)
#merge = drop_features.merge(pleasant, on='DATE')
#merge

# %%
# Check data types
#merge.dtypes

# %%
# Convert the 'DATE' column to string type
#merge['DATE'] = merge['DATE'].astype(str)

# Extract the year from the 'DATE' column and convert it to integer type
#merge['Year'] = merge['DATE'].str[:4].astype(int)

# Filter the DataFrame for the years between 2012 and 2022
#features = merge[(merge['Year'] >= 2012) & (merge['Year'] <= 2022)]

# Now filtered_df contains data only for the years between 2012 and 2022

# %%
# Use datetime instead of string - dont merge data


# Convert 'DATE' column to string
drop_features['DATE'] = drop_features['DATE'].astype(str)

# Convert string dates to datetime format
drop_features['DATE'] = pd.to_datetime(drop_features['DATE'], format='%Y%m%d')

# Verify the conversion
drop_features['DATE']
# Out:
# 0       1960-01-01
# 1       1960-01-02
# 2       1960-01-03
# 3       1960-01-04
# 4       1960-01-05
#            ...
# 22945   2022-10-27
# 22946   2022-10-28
# 22947   2022-10-29
# 22948   2022-10-30
# 22949   2022-10-31
# Name: DATE, Length: 22950, dtype: datetime64[ns]

# %%
# Define the start and end dates of the range
start_date = '2000-01-01'
end_date = '2010-10-31'

# Filter data based on the specified range
features = drop_features[(drop_features['DATE'] >= start_date) & (drop_features['DATE'] <= end_date)]

# View new dataframe features
features
# Out:
#             DATE  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 14610 2000-01-01               1.08             -0.03            1.19
# 14611 2000-01-02               1.08             -0.03            1.01
# 14612 2000-01-03              -0.17             -0.03            0.46
# 14613 2000-01-04               0.66             -0.03            0.28
# 14614 2000-01-05              -0.17             -0.03            1.28
# ...          ...                ...               ...             ...
# 18562 2010-10-27              -0.17             -1.53           -0.44
# 18563 2010-10-28              -0.17             -1.26           -0.71
# 18564 2010-10-29              -0.59              0.52           -0.62
# 18565 2010-10-30               0.66             -1.80            0.10
# 18566 2010-10-31               0.24             -0.98            0.74
#
#        BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 14610            1.62                   -1.23                -0.39
# 14611            2.11                   -1.18                -0.45
# 14612            2.05                   -0.91                -0.45
# 14613            1.25                   -0.77                 0.26
# 14614            1.01                   -0.90                -0.31
# ...               ...                     ...                  ...
# 18562            1.40                   -0.36                -0.45
# 18563            0.96                   -0.56                -0.45
# 18564           -0.64                   -0.24                -0.45
# 18565           -1.59                   -0.82                -0.45
# 18566           -2.43                   -0.95                -0.45
#
#        BASEL_snow_depth  BASEL_sunshine  BASEL_temp_mean  ...  \
# 14610             -0.18           -1.07            -1.02  ...
# 14611             -0.18           -1.07            -0.92  ...
# 14612             -0.18           -0.21            -1.11  ...
# 14613             -0.18            0.54            -0.88  ...
# 14614             -0.18           -0.21            -0.60  ...
# ...                 ...             ...              ...  ...
# 18562             -0.18            0.23            -0.57  ...
# 18563             -0.18           -0.32            -0.34  ...
# 18564             -0.18            0.72            -0.07  ...
# 18565             -0.18           -0.90            -0.05  ...
# 18566             -0.18           -0.95            -0.05  ...
#
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 14610                  0.17               0.90               0.86
# 14611                  1.40               1.32               0.32
# 14612                 -1.06              -0.50               0.11
# 14613                  0.17              -0.93              -0.40
# 14614                  0.78              -0.22              -1.73
# ...                     ...                ...                ...
# 18562                 -0.44              -0.08              -0.00
# 18563                 -0.44              -0.08              -0.00
# 18564                 -0.44              -0.08              -0.00
# 18565                 -0.44              -0.08              -0.00
# 18566                 -0.44              -0.08              -0.00
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 14610                      -1.08                   -0.37                -0.02
# 14611                      -1.18                    0.01                -0.02
# 14612                      -1.08                    0.75                -0.02
# 14613                      -0.91                   -0.09                -0.02
# 14614                      -1.20                   -0.10                -0.02
# ...                          ...                     ...                  ...
# 18562                      -0.65                   -0.01                -0.02
# 18563                      -1.05                   -0.01                -0.02
# 18564                      -0.82                   -0.01                -0.02
# 18565                      -0.50                   -0.01                -0.02
# 18566                      -0.50                   -0.01                -0.02
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 14610              -0.83               -1.24              -1.59
# 14611              -1.04               -0.34              -0.16
# 14612              -0.68               -0.64              -0.16
# 14613               0.01               -0.79              -0.79
# 14614              -1.04               -0.91              -1.07
# ...                  ...                 ...                ...
# 18562              -0.02               -0.01              -0.00
# 18563              -0.02               -0.01              -0.00
# 18564              -0.02               -0.01              -0.00
# 18565              -0.02               -0.01              -0.00
# 18566              -0.02               -0.01              -0.00
#
#        VALENTIA_temp_max
# 14610              -0.72
# 14611              -0.84
# 14612              -1.04
# 14613              -1.67
# 14614              -0.64
# ...                  ...
# 18562               0.46
# 18563               0.54
# 18564              -0.15
# 18565               0.31
# 18566              -0.26
#
# [3957 rows x 150 columns]

# %%
# Save features scaled and merged dataset without 3 weather stations [ROMA, GDANSK, TOURS]

features.to_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'scaled-features-last-decade.csv'), index=False)

# %%
features.dtypes
# Out:
# DATE                   datetime64[ns]
# BASEL_cloud_cover             float64
# BASEL_wind_speed              float64
# BASEL_humidity                float64
# BASEL_pressure                float64
#                             ...
# VALENTIA_snow_depth           float64
# VALENTIA_sunshine             float64
# VALENTIA_temp_mean            float64
# VALENTIA_temp_min             float64
# VALENTIA_temp_max             float64
# Length: 150, dtype: object

# %%
# Filter for columns starting with 'DATE' and 'VALENTIA'
valentia_c = features.filter(like='VALENTIA')
dc = features.filter(like='DATE')
valentia_dc = valentia_c.merge(dc, left_index=True, right_index=True)

# Print the DataFrame
valentia_dc
# Out:
#        VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 14610                  0.17               0.90               0.86
# 14611                  1.40               1.32               0.32
# 14612                 -1.06              -0.50               0.11
# 14613                  0.17              -0.93              -0.40
# 14614                  0.78              -0.22              -1.73
# ...                     ...                ...                ...
# 18562                 -0.44              -0.08              -0.00
# 18563                 -0.44              -0.08              -0.00
# 18564                 -0.44              -0.08              -0.00
# 18565                 -0.44              -0.08              -0.00
# 18566                 -0.44              -0.08              -0.00
#
#        VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 14610                      -1.08                   -0.37                -0.02
# 14611                      -1.18                    0.01                -0.02
# 14612                      -1.08                    0.75                -0.02
# 14613                      -0.91                   -0.09                -0.02
# 14614                      -1.20                   -0.10                -0.02
# ...                          ...                     ...                  ...
# 18562                      -0.65                   -0.01                -0.02
# 18563                      -1.05                   -0.01                -0.02
# 18564                      -0.82                   -0.01                -0.02
# 18565                      -0.50                   -0.01                -0.02
# 18566                      -0.50                   -0.01                -0.02
#
#        VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 14610              -0.83               -1.24              -1.59
# 14611              -1.04               -0.34              -0.16
# 14612              -0.68               -0.64              -0.16
# 14613               0.01               -0.79              -0.79
# 14614              -1.04               -0.91              -1.07
# ...                  ...                 ...                ...
# 18562              -0.02               -0.01              -0.00
# 18563              -0.02               -0.01              -0.00
# 18564              -0.02               -0.01              -0.00
# 18565              -0.02               -0.01              -0.00
# 18566              -0.02               -0.01              -0.00
#
#        VALENTIA_temp_max       DATE
# 14610              -0.72 2000-01-01
# 14611              -0.84 2000-01-02
# 14612              -1.04 2000-01-03
# 14613              -1.67 2000-01-04
# 14614              -0.64 2000-01-05
# ...                  ...        ...
# 18562               0.46 2010-10-27
# 18563               0.54 2010-10-28
# 18564              -0.15 2010-10-29
# 18565               0.31 2010-10-30
# 18566              -0.26 2010-10-31
#
# [3957 rows x 11 columns]

# %%
# Use pleasant weather datetime for merge


# Convert 'DATE' column to string
pleasant['DATE'] = drop_features['DATE'].astype(str)

# Convert string dates to datetime format
pleasant['DATE'] = pd.to_datetime(drop_features['DATE'], format='%Y%m%d')

# Verify the conversion
pleasant['DATE']

# Define the start and end dates of the range
start_date = '2000-01-01'
end_date = '2010-10-31'

# Filter data based on the specified range
features_p = pleasant[(pleasant['DATE'] >= start_date) & (pleasant['DATE'] <= end_date)]

# View new dataframe features
features_p
# Out:
#             DATE  BASEL_pleasant_weather  BELGRADE_pleasant_weather  \
# 14610 2000-01-01                       0                          0
# 14611 2000-01-02                       0                          0
# 14612 2000-01-03                       0                          0
# 14613 2000-01-04                       0                          0
# 14614 2000-01-05                       0                          0
# ...          ...                     ...                        ...
# 18562 2010-10-27                       0                          0
# 18563 2010-10-28                       0                          0
# 18564 2010-10-29                       0                          0
# 18565 2010-10-30                       0                          0
# 18566 2010-10-31                       0                          1
#
#        BUDAPEST_pleasant_weather  DEBILT_pleasant_weather  \
# 14610                          0                        0
# 14611                          0                        0
# 14612                          0                        0
# 14613                          0                        0
# 14614                          0                        0
# ...                          ...                      ...
# 18562                          0                        0
# 18563                          0                        0
# 18564                          0                        0
# 18565                          0                        0
# 18566                          0                        0
#
#        DUSSELDORF_pleasant_weather  HEATHROW_pleasant_weather  \
# 14610                            0                          0
# 14611                            0                          0
# 14612                            0                          0
# 14613                            0                          0
# 14614                            0                          0
# ...                            ...                        ...
# 18562                            0                          0
# 18563                            0                          0
# 18564                            0                          0
# 18565                            0                          0
# 18566                            0                          0
#
#        KASSEL_pleasant_weather  LJUBLJANA_pleasant_weather  \
# 14610                        0                           0
# 14611                        0                           0
# 14612                        0                           0
# 14613                        0                           0
# 14614                        0                           0
# ...                        ...                         ...
# 18562                        0                           0
# 18563                        0                           0
# 18564                        0                           0
# 18565                        0                           0
# 18566                        0                           0
#
#        MAASTRICHT_pleasant_weather  MADRID_pleasant_weather  \
# 14610                            0                        0
# 14611                            0                        0
# 14612                            0                        0
# 14613                            0                        0
# 14614                            0                        0
# ...                            ...                      ...
# 18562                            0                        1
# 18563                            0                        1
# 18564                            0                        0
# 18565                            0                        0
# 18566                            0                        0
#
#        MUNCHENB_pleasant_weather  OSLO_pleasant_weather  \
# 14610                          0                      0
# 14611                          0                      0
# 14612                          0                      0
# 14613                          0                      0
# 14614                          0                      0
# ...                          ...                    ...
# 18562                          0                      0
# 18563                          0                      0
# 18564                          1                      0
# 18565                          1                      0
# 18566                          0                      0
#
#        SONNBLICK_pleasant_weather  STOCKHOLM_pleasant_weather  \
# 14610                           0                           0
# 14611                           0                           0
# 14612                           0                           0
# 14613                           0                           0
# 14614                           0                           0
# ...                           ...                         ...
# 18562                           0                           0
# 18563                           0                           0
# 18564                           0                           0
# 18565                           0                           0
# 18566                           0                           0
#
#        VALENTIA_pleasant_weather
# 14610                          0
# 14611                          0
# 14612                          0
# 14613                          0
# 14614                          0
# ...                          ...
# 18562                          0
# 18563                          0
# 18564                          0
# 18565                          0
# 18566                          0
#
# [3957 rows x 16 columns]

# %%
# Subset the DataFrame for the specified columns
features_s = features_p[['DATE', 'VALENTIA_pleasant_weather']]
features_s
# Out:
#             DATE  VALENTIA_pleasant_weather
# 14610 2000-01-01                          0
# 14611 2000-01-02                          0
# 14612 2000-01-03                          0
# 14613 2000-01-04                          0
# 14614 2000-01-05                          0
# ...          ...                        ...
# 18562 2010-10-27                          0
# 18563 2010-10-28                          0
# 18564 2010-10-29                          0
# 18565 2010-10-30                          0
# 18566 2010-10-31                          0
#
# [3957 rows x 2 columns]

# %%
# Merge valentia with valentia_pleasant_weather

valentia_m = valentia_dc.merge(features_s, on='DATE')
valentia_m
# Out:
#       VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 0                     0.17               0.90               0.86
# 1                     1.40               1.32               0.32
# 2                    -1.06              -0.50               0.11
# 3                     0.17              -0.93              -0.40
# 4                     0.78              -0.22              -1.73
# ...                    ...                ...                ...
# 3952                 -0.44              -0.08              -0.00
# 3953                 -0.44              -0.08              -0.00
# 3954                 -0.44              -0.08              -0.00
# 3955                 -0.44              -0.08              -0.00
# 3956                 -0.44              -0.08              -0.00
#
#       VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 0                         -1.08                   -0.37                -0.02
# 1                         -1.18                    0.01                -0.02
# 2                         -1.08                    0.75                -0.02
# 3                         -0.91                   -0.09                -0.02
# 4                         -1.20                   -0.10                -0.02
# ...                         ...                     ...                  ...
# 3952                      -0.65                   -0.01                -0.02
# 3953                      -1.05                   -0.01                -0.02
# 3954                      -0.82                   -0.01                -0.02
# 3955                      -0.50                   -0.01                -0.02
# 3956                      -0.50                   -0.01                -0.02
#
#       VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 0                 -0.83               -1.24              -1.59
# 1                 -1.04               -0.34              -0.16
# 2                 -0.68               -0.64              -0.16
# 3                  0.01               -0.79              -0.79
# 4                 -1.04               -0.91              -1.07
# ...                 ...                 ...                ...
# 3952              -0.02               -0.01              -0.00
# 3953              -0.02               -0.01              -0.00
# 3954              -0.02               -0.01              -0.00
# 3955              -0.02               -0.01              -0.00
# 3956              -0.02               -0.01              -0.00
#
#       VALENTIA_temp_max       DATE  VALENTIA_pleasant_weather
# 0                 -0.72 2000-01-01                          0
# 1                 -0.84 2000-01-02                          0
# 2                 -1.04 2000-01-03                          0
# 3                 -1.67 2000-01-04                          0
# 4                 -0.64 2000-01-05                          0
# ...                 ...        ...                        ...
# 3952               0.46 2010-10-27                          0
# 3953               0.54 2010-10-28                          0
# 3954              -0.15 2010-10-29                          0
# 3955               0.31 2010-10-30                          0
# 3956              -0.26 2010-10-31                          0
#
# [3957 rows x 12 columns]

# %%
# Realign datafram
valentia_m = valentia_m[['DATE', 'VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure',
                         'VALENTIA_global_radiation', 'VALENTIA_precipitation', 'VALENTIA_snow_depth',
                         'VALENTIA_sunshine', 'VALENTIA_temp_mean', 'VALENTIA_temp_min', 'VALENTIA_temp_max',
                         'VALENTIA_pleasant_weather']]
valentia_m
# Out:
#            DATE  VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 0    2000-01-01                  0.17               0.90               0.86
# 1    2000-01-02                  1.40               1.32               0.32
# 2    2000-01-03                 -1.06              -0.50               0.11
# 3    2000-01-04                  0.17              -0.93              -0.40
# 4    2000-01-05                  0.78              -0.22              -1.73
# ...         ...                   ...                ...                ...
# 3952 2010-10-27                 -0.44              -0.08              -0.00
# 3953 2010-10-28                 -0.44              -0.08              -0.00
# 3954 2010-10-29                 -0.44              -0.08              -0.00
# 3955 2010-10-30                 -0.44              -0.08              -0.00
# 3956 2010-10-31                 -0.44              -0.08              -0.00
#
#       VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 0                         -1.08                   -0.37                -0.02
# 1                         -1.18                    0.01                -0.02
# 2                         -1.08                    0.75                -0.02
# 3                         -0.91                   -0.09                -0.02
# 4                         -1.20                   -0.10                -0.02
# ...                         ...                     ...                  ...
# 3952                      -0.65                   -0.01                -0.02
# 3953                      -1.05                   -0.01                -0.02
# 3954                      -0.82                   -0.01                -0.02
# 3955                      -0.50                   -0.01                -0.02
# 3956                      -0.50                   -0.01                -0.02
#
#       VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 0                 -0.83               -1.24              -1.59
# 1                 -1.04               -0.34              -0.16
# 2                 -0.68               -0.64              -0.16
# 3                  0.01               -0.79              -0.79
# 4                 -1.04               -0.91              -1.07
# ...                 ...                 ...                ...
# 3952              -0.02               -0.01              -0.00
# 3953              -0.02               -0.01              -0.00
# 3954              -0.02               -0.01              -0.00
# 3955              -0.02               -0.01              -0.00
# 3956              -0.02               -0.01              -0.00
#
#       VALENTIA_temp_max  VALENTIA_pleasant_weather
# 0                 -0.72                          0
# 1                 -0.84                          0
# 2                 -1.04                          0
# 3                 -1.67                          0
# 4                 -0.64                          0
# ...                 ...                        ...
# 3952               0.46                          0
# 3953               0.54                          0
# 3954              -0.15                          0
# 3955               0.31                          0
# 3956              -0.26                          0
#
# [3957 rows x 12 columns]

# %%
# Drop date column for hierarchial clustering
valentia_m = valentia_m.drop(columns=['DATE'])
valentia_m
# Out:
#       VALENTIA_cloud_cover  VALENTIA_humidity  VALENTIA_pressure  \
# 0                     0.17               0.90               0.86
# 1                     1.40               1.32               0.32
# 2                    -1.06              -0.50               0.11
# 3                     0.17              -0.93              -0.40
# 4                     0.78              -0.22              -1.73
# ...                    ...                ...                ...
# 3952                 -0.44              -0.08              -0.00
# 3953                 -0.44              -0.08              -0.00
# 3954                 -0.44              -0.08              -0.00
# 3955                 -0.44              -0.08              -0.00
# 3956                 -0.44              -0.08              -0.00
#
#       VALENTIA_global_radiation  VALENTIA_precipitation  VALENTIA_snow_depth  \
# 0                         -1.08                   -0.37                -0.02
# 1                         -1.18                    0.01                -0.02
# 2                         -1.08                    0.75                -0.02
# 3                         -0.91                   -0.09                -0.02
# 4                         -1.20                   -0.10                -0.02
# ...                         ...                     ...                  ...
# 3952                      -0.65                   -0.01                -0.02
# 3953                      -1.05                   -0.01                -0.02
# 3954                      -0.82                   -0.01                -0.02
# 3955                      -0.50                   -0.01                -0.02
# 3956                      -0.50                   -0.01                -0.02
#
#       VALENTIA_sunshine  VALENTIA_temp_mean  VALENTIA_temp_min  \
# 0                 -0.83               -1.24              -1.59
# 1                 -1.04               -0.34              -0.16
# 2                 -0.68               -0.64              -0.16
# 3                  0.01               -0.79              -0.79
# 4                 -1.04               -0.91              -1.07
# ...                 ...                 ...                ...
# 3952              -0.02               -0.01              -0.00
# 3953              -0.02               -0.01              -0.00
# 3954              -0.02               -0.01              -0.00
# 3955              -0.02               -0.01              -0.00
# 3956              -0.02               -0.01              -0.00
#
#       VALENTIA_temp_max  VALENTIA_pleasant_weather
# 0                 -0.72                          0
# 1                 -0.84                          0
# 2                 -1.04                          0
# 3                 -1.67                          0
# 4                 -0.64                          0
# ...                 ...                        ...
# 3952               0.46                          0
# 3953               0.54                          0
# 3954              -0.15                          0
# 3955               0.31                          0
# 3956              -0.26                          0
#
# [3957 rows x 11 columns]

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 4. Create dendrogram
# - ### Single

# %%
distance_single = linkage(valentia_m.loc[:,['VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure', 'VALENTIA_global_radiation',
                                         'VALENTIA_precipitation', 'VALENTIA_snow_depth', 'VALENTIA_sunshine', 'VALENTIA_temp_mean',
                                         'VALENTIA_temp_min', 'VALENTIA_temp_max']], method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Single Method",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Single Method')

# %% [markdown]
# - **note:** no discernable clusters

# %% [markdown]
# - ### Complete

# %%
distance_complete = linkage(valentia_m.loc[:,['VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure', 'VALENTIA_global_radiation',
                                         'VALENTIA_precipitation', 'VALENTIA_snow_depth', 'VALENTIA_sunshine', 'VALENTIA_temp_mean',
                                         'VALENTIA_temp_min', 'VALENTIA_temp_max']], method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_complete, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Complete Method",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Complete Method')

# %% [markdown]
# - **note:** no discernable clusters

# %% [markdown]
# - ### Average

# %%
distance_average = linkage(valentia_m.loc[:,['VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure', 'VALENTIA_global_radiation',
                                         'VALENTIA_precipitation', 'VALENTIA_snow_depth', 'VALENTIA_sunshine', 'VALENTIA_temp_mean',
                                         'VALENTIA_temp_min', 'VALENTIA_temp_max']], method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_average, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Average Method",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Average Method')

# %% [markdown]
# - **note:** similar to complete method, no discernable clusters

# %% [markdown]
# - ### Ward

# %%
distance_ward = linkage(valentia_m.loc[:,['VALENTIA_cloud_cover', 'VALENTIA_humidity', 'VALENTIA_pressure', 'VALENTIA_global_radiation',
                                         'VALENTIA_precipitation', 'VALENTIA_snow_depth', 'VALENTIA_sunshine', 'VALENTIA_temp_mean',
                                         'VALENTIA_temp_min', 'VALENTIA_temp_max']], method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_ward, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("VALENTIA - Dendrogram Ward Method",fontsize=18)
# Out:
# Text(0.5, 0.98, 'VALENTIA - Dendrogram Ward Method')

# %% [markdown]
# - **note:** 2-4 mostly-discernable clusters, most optimal method. These discernable clusters represent that the model is finding associated patterns within the data efficiently.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ## 5. Dimensionality reduction
# - #### PCA

# %%
#Run the PCA model, reducing to 5 components (%50), as we have 10 components in our weather_scaled_data
pca = PCA(n_components=5)
principalComponents = pca.fit_transform(valentia_m)

# %%
principalComponents
# Out:
# array([[ 1.17863901, -1.52207892, -1.702181  ,  1.24008222, -0.93003383],
#        [ 1.59590036,  0.26097497, -2.07024982,  0.71971953, -0.38994652],
#        [ 1.2986044 , -1.33328869, -0.0650916 ,  0.32458669,  0.29552562],
#        ...,
#        [ 0.26160964, -0.41362139, -0.28161082,  0.08919384, -0.01885284],
#        [ 0.04144147, -0.19680636, -0.08738633,  0.0605801 , -0.07255345],
#        [ 0.19144221, -0.4399372 , -0.19252839,  0.06023932, -0.07553392]])

# %%
#Make a dataframe of the new components
dfPCA = pd.DataFrame(principalComponents, columns=['PCA1', 'PCA2', 'PCA3', 'PCA4', 'PCA5'])

# %%
dfPCA
# Out:
#       PCA1  PCA2  PCA3  PCA4  PCA5
# 0     1.18 -1.52 -1.70  1.24 -0.93
# 1     1.60  0.26 -2.07  0.72 -0.39
# 2     1.30 -1.33 -0.07  0.32  0.30
# 3     0.97 -2.01 -0.71 -0.38  0.47
# 4     1.68 -1.15 -1.62 -1.44  0.20
# ...    ...   ...   ...   ...   ...
# 3952  0.05 -0.15 -0.11  0.07 -0.04
# 3953  0.16 -0.14 -0.24  0.11  0.03
# 3954  0.26 -0.41 -0.28  0.09 -0.02
# 3955  0.04 -0.20 -0.09  0.06 -0.07
# 3956  0.19 -0.44 -0.19  0.06 -0.08
#
# [3957 rows x 5 columns]

# %%
#Add the weather outcomes to the dataframe to show the relationship
V_answers = valentia_m['VALENTIA_pleasant_weather']
V_answers
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3952    0
# 3953    0
# 3954    0
# 3955    0
# 3956    0
# Name: VALENTIA_pleasant_weather, Length: 3957, dtype: int64

# %%
dfPCA['V_answers']= valentia_m['VALENTIA_pleasant_weather']

# %%
dfPCA
# Out:
#       PCA1  PCA2  PCA3  PCA4  PCA5  V_answers
# 0     1.18 -1.52 -1.70  1.24 -0.93          0
# 1     1.60  0.26 -2.07  0.72 -0.39          0
# 2     1.30 -1.33 -0.07  0.32  0.30          0
# 3     0.97 -2.01 -0.71 -0.38  0.47          0
# 4     1.68 -1.15 -1.62 -1.44  0.20          0
# ...    ...   ...   ...   ...   ...        ...
# 3952  0.05 -0.15 -0.11  0.07 -0.04          0
# 3953  0.16 -0.14 -0.24  0.11  0.03          0
# 3954  0.26 -0.41 -0.28  0.09 -0.02          0
# 3955  0.04 -0.20 -0.09  0.06 -0.07          0
# 3956  0.19 -0.44 -0.19  0.06 -0.08          0
#
# [3957 rows x 6 columns]

# %%
dfPCA['V_answers'].value_counts(dropna=False)
# Out:
# V_answers
# 0    3756
# 1     201
# Name: count, dtype: int64

# %%
# PLot the two components, color coded by VALENTIA pleasant weather outcomes (V_answers)
sns.set_theme()
g = sns.catplot(x="PCA1", y="PCA2", palette='Set1', hue="V_answers", data=dfPCA)
plt.xticks([0, 40, 80, 120, 149])
# Out:
# ([<matplotlib.axis.XTick at 0x284fc7b3c90>,
#   <matplotlib.axis.XTick at 0x2849085c090>,
#   <matplotlib.axis.XTick at 0x284fd3758d0>,
#   <matplotlib.axis.XTick at 0x284897b5fd0>,
#   <matplotlib.axis.XTick at 0x284fc596450>],
#  [Text(0, 0, '-4.979620741275019'),
#   Text(40, 0, '-3.6857286941572363'),
#   Text(80, 0, '-3.3325099209556264'),
#   Text(120, 0, '-3.0825473491141584'),
#   Text(149, 0, '-2.888659385097907')])

# %%
sns.pairplot(dfPCA, hue="V_answers", palette='Set1')

# %%
# From 2000-01-01 - 2010-12-31, VALENTIA has had more non pleasant days then pleasant days.
# In the past decade VALENTIA has had no pleasant weather days.

# %%
# Run the PCA model, reducing to 1 component
pca = PCA(n_components=1)
principalComponents2 = pca.fit_transform(valentia_m)

# %%
principalComponents2
# Out:
# array([[1.17863901],
#        [1.59590036],
#        [1.2986044 ],
#        ...,
#        [0.26160964],
#        [0.04144147],
#        [0.19144221]])

# %%
# Add the binary outcomes for VALENTIA pleasant weather to the dataframe to show the relationship
dfPCA2 = pd.DataFrame(principalComponents2, columns=['PCA1'])
dfPCA2['y']= 0
dfPCA2['V_answers']= valentia_m['VALENTIA_pleasant_weather']
dfPCA2
# Out:
#       PCA1  y  V_answers
# 0     1.18  0          0
# 1     1.60  0          0
# 2     1.30  0          0
# 3     0.97  0          0
# 4     1.68  0          0
# ...    ... ..        ...
# 3952  0.05  0          0
# 3953  0.16  0          0
# 3954  0.26  0          0
# 3955  0.04  0          0
# 3956  0.19  0          0
#
# [3957 rows x 3 columns]

# %%
# PLot the component, color coded by pleasant weather answers
sns.set_theme()
g = sns.catplot(x="PCA1", y='y', palette='Set1', hue="V_answers", data=dfPCA2)
plt.xticks([0, 40, 80, 120, 149])
# Out:
# ([<matplotlib.axis.XTick at 0x28489c58790>,
#   <matplotlib.axis.XTick at 0x28496cea5d0>,
#   <matplotlib.axis.XTick at 0x28496dcfdd0>,
#   <matplotlib.axis.XTick at 0x284a1e99650>,
#   <matplotlib.axis.XTick at 0x284893c1050>],
#  [Text(0, 0, '-4.979620741275009'),
#   Text(40, 0, '-3.6857286941572367'),
#   Text(80, 0, '-3.332509920955619'),
#   Text(120, 0, '-3.0825473491141544'),
#   Text(149, 0, '-2.888659385097905')])

# %%
# # Reduced to 1 component - from 2000-01-01 - 2010-12-31, VALENTIA has had more non pleasant days then pleasant days.
# No pleasant weather days in the past decade for VALENTIA weather statio.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %%
# Export datasets

# %%
valentia_m.to_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'valentia_scaled_decade.csv'), index=False)

# %%
dfPCA.to_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'PCA1.csv'), index=False)

# %%
dfPCA2.to_csv(os.path.join(path, '02 Data Sets', 'Unsupervised', 'PCA2.csv'), index=False)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
