# %% [markdown]
# # 2.5 Visual Weather Systems - CNN
# ### The following script contains the following:
#
# #### 1. Import data libraries
# #### 2. Input additional requirements
# #### 3. Load data and
# #### 4. Create CNN model
# #### 5. Plot accuracy and loss
# #### 6. Display confusion matrix
# #### 7. Generate images and predictions
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 1. Import data libraries
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import warnings
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import Input
from keras.models import Sequential
from keras.models import Model
from keras.layers import Conv1D, Conv2D, Dense, BatchNormalization, Flatten, MaxPooling2D, Activation, Dropout
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %%
#2. Input requirements
#show all plots
# %matplotlib inline

#turning off warning feature
warnings.filterwarnings('ignore')

# %%
# 3. Load data and images
path = r'Multi-class Weather Dataset'
folders = os.listdir(path)
print(folders)
# Out:
# ['Cloudy', 'Rain', 'Shine', 'Sunrise']

# %%
#this will load in the pictures and rescale them to 250x250pixels

datagenerator = ImageDataGenerator(rescale=1/255, validation_split=0.2)
train_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='training',
)

test_generator = datagenerator.flow_from_directory(
    path,
    target_size=(250 , 250),
    batch_size=32,
    subset='validation',
)
# Out:
# Found 901 images belonging to 4 classes.
# Found 224 images belonging to 4 classes.

# %%
# 4. Create CNN model
#this is a CNN to categorize the weather images

epochs = 45  # Increase epochs
dropout_rate = 0.5  # Adjust dropout rate
learning_rate = 0.001  # Adjust learning rate

inputs = Input(shape=(250, 250, 3))

x = Conv2D(32, (5,5), activation = 'relu')(inputs)
x = MaxPooling2D(3,3)(x)
x = Conv2D(64, (5,5) , activation = 'relu')(x)
x = MaxPooling2D((3,3))(x)
x = Conv2D(128 , (5,5) , activation = 'relu')(x)
x = MaxPooling2D(3,3)(x)
x = Flatten()(x)
x = Dropout(dropout_rate,seed=5)(x)  # Adjusted dropout rate
x = Dense(128 , activation = 'relu')(x)

outputs = Dense(4, activation = 'softmax')(x)

model:Model = Model(inputs=inputs, outputs=outputs)

# %%
#compile and run the model
#how many epochs are required to generate an accurate model?

model.compile(optimizer=Adam(learning_rate=learning_rate), loss="categorical_crossentropy", metrics=["accuracy"]) #mean_squared_error
model.fit(
    train_generator, 
    epochs=epochs,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    validation_data=test_generator,
    validation_steps=test_generator.n // test_generator.batch_size
)
# Out:
# Epoch 1/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.4192 - loss: 1.1552 - val_accuracy: 0.6652 - val_loss: 0.9131
# Epoch 2/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.8204 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 3/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6303 - loss: 0.7856 - val_accuracy: 0.7232 - val_loss: 0.5836
# Epoch 4/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7188 - loss: 0.7471 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 5/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8061 - loss: 0.5591 - val_accuracy: 0.7009 - val_loss: 0.6569
# Epoch 6/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7812 - loss: 0.5104 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 7/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8183 - loss: 0.4881 - val_accuracy: 0.8036 - val_loss: 0.5512
# Epoch 8/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8750 - loss: 0.3547 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 9/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8028 - loss: 0.5164 - val_accuracy: 0.8259 - val_loss: 0.4367
# Epoch 10/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8000 - loss: 0.3000 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 11/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8694 - loss: 0.3329 - val_accuracy: 0.8482 - val_loss: 0.3832
# Epoch 12/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7500 - loss: 0.4879 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 13/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8901 - loss: 0.3000 - val_accuracy: 0.8170 - val_loss: 0.4253
# Epoch 14/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.5773 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 15/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8851 - loss: 0.2912 - val_accuracy: 0.7946 - val_loss: 0.4481
# Epoch 16/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8438 - loss: 0.3140 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 17/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8936 - loss: 0.3003 - val_accuracy: 0.8170 - val_loss: 0.4528
# Epoch 18/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 807us/step - accuracy: 0.9688 - loss: 0.1419 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 19/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8928 - loss: 0.2847 - val_accuracy: 0.8304 - val_loss: 0.4113
# Epoch 20/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9375 - loss: 0.2007 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 21/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8930 - loss: 0.3123 - val_accuracy: 0.8214 - val_loss: 0.4793
# Epoch 22/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9688 - loss: 0.1248 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 23/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9283 - loss: 0.2014 - val_accuracy: 0.8080 - val_loss: 0.5095
# Epoch 24/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9375 - loss: 0.1943 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 25/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8963 - loss: 0.2716 - val_accuracy: 0.8036 - val_loss: 0.4924
# Epoch 26/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8750 - loss: 0.3570 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 27/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9348 - loss: 0.1642 - val_accuracy: 0.8482 - val_loss: 0.3972
# Epoch 28/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 0.0681 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 29/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9075 - loss: 0.2385 - val_accuracy: 0.8304 - val_loss: 0.4681
# Epoch 30/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9062 - loss: 0.2381 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 31/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9070 - loss: 0.2846 - val_accuracy: 0.8036 - val_loss: 0.5366
# Epoch 32/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 1.0000 - loss: 0.1397 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 33/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8930 - loss: 0.3032 - val_accuracy: 0.8527 - val_loss: 0.3735
# Epoch 34/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8000 - loss: 0.2881 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 35/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8639 - loss: 0.3859 - val_accuracy: 0.8036 - val_loss: 0.4684
# Epoch 36/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9688 - loss: 0.1509 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 37/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9283 - loss: 0.1785 - val_accuracy: 0.8438 - val_loss: 0.3319
# Epoch 38/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 39/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9433 - loss: 0.1649 - val_accuracy: 0.8125 - val_loss: 0.5484
# Epoch 40/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.9688 - loss: 0.0891 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 41/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.9213 - loss: 0.2199 - val_accuracy: 0.8348 - val_loss: 0.4269
# Epoch 42/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 1.0000 - loss: 0.0543 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 43/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9108 - loss: 0.2089 - val_accuracy: 0.8616 - val_loss: 0.3959
# Epoch 44/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8750 - loss: 0.3440 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 45/45
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9422 - loss: 0.1819 - val_accuracy: 0.8527 - val_loss: 0.4147

# %% [markdown]
# - **notes:** 94% convergence at [45] epochs.

# %%
# 5. Plot accuracy and loss
results = pd.DataFrame(model.history.history)

# %%
results[['loss','val_loss']].plot(title='Model Loss - 45 Epochs')
plt.savefig('./loss.png')

# %%
# Validation loss should typically be a non-zero value

# %%
results[['accuracy','val_accuracy']].plot(title='Model Acurracy -  Epochs')
plt.savefig('./accuracy.png')

# %%
# Print the accuracy and loss
print("Accuracy: {}, Val_Accuracy: {}".format(results['accuracy'].iloc[-1], results['val_accuracy'].iloc[-1]))
print("Loss: {}, Val_Loss: {}".format(results['loss'].iloc[-1], results['val_loss'].iloc[-1]))

# Validation accuracy should typically be a non-zero value between 0 and 1, representing the model's performance on a separate validation dataset.
# Out:
# Accuracy: 0.9470655918121338, Val_Accuracy: 0.8526785969734192
# Loss: 0.15906193852424622, Val_Loss: 0.41473737359046936

# %%
# 5. Display confusion matrix
#collect n batches of images and display the confusion matrix for them.

class_names = ['Cloudy', 'Rain', 'Shine', 'Sunrise']
n = 10 #<--you can change the number of batches selected.

image_batch, classes_batch = next(test_generator)

for batch in range(n):
    temp = next(test_generator)
    image_batch = np.concatenate((image_batch, temp[0]))
    classes_batch = np.concatenate((classes_batch, temp[1]))

classes_batch = classes_batch
y_predict = model.predict(image_batch)

#Confusion matrix for training data
cm = confusion_matrix(y_pred = [np.argmax(x) for x in y_predict], y_true = [np.argmax(x) for x in classes_batch])
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 314ms/step

# %%
# 6. Generate images and their predictions
#This function will display a number of random images as well as the predictions for the type of weather.

def predict_one(model, num_images = None):  
    image_batch, classes_batch = next(test_generator)
    predicted_batch = model.predict(image_batch)
    for k in range(0,image_batch.shape[0] if num_images is None else num_images):
        image = image_batch[k]
        real_class = class_names[np.argmax(classes_batch[k])]
        predicted_class = class_names[np.argmax(predicted_batch[k])]
        value_predicted = predicted_batch[k]
        isTrue = (real_class == predicted_class)
        plt.figure(k)
        plt.title(str("Correct Prediction" if isTrue else "Incorrect Prediction") + ' - class: ' + real_class + ' - ' + 'predicted: ' + predicted_class + str(value_predicted))
        plt.axis('off')
        plt.savefig('./' + real_class + '_' + predicted_class + '_' + str(value_predicted) + '.png')
        plt.imshow(image)

# %%
predict_one(model, 3) #<--you can show multiple pictures with this command. Just fill in the number you want to see.
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------
